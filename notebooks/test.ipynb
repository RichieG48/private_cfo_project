# %%
import os
from google.genai import genai
from dotenv import load_dotenv

# Load your .env file
load_dotenv()

api_key = "AIzaSyCjT1iyuqopZkYxBb0DCo5YA87gDsow2uo"

if not api_key:
    print("❌ Error: No GOOGLE_API_KEY found in .env")
else:
    print(f"✅ Found API Key: {api_key[:5]}...")
    
    # Configure the SDK
    genai.configure(api_key=api_key)

    print("\nListing available models for your key:")
    print("-" * 40)
    
    try:
        # List all models
        for m in genai.list_models():
            # We only care about models that can generate content (chat)
            if 'generateContent' in m.supported_generation_methods:
                print(f"Name: {m.name}")
                print(f"Display Name: {m.display_name}")
                print("-" * 40)
    except Exception as e:
        print(f"❌ Error connecting to Google: {e}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 import os
# ----> 2 from google.genai import genai
#       3 from dotenv import load_dotenv
#       5 # Load your .env file
#
# ImportError: cannot import name 'genai' from 'google.genai' (/Users/gabrielrichard/private_cfo_project/.venv/lib/python3.11/site-packages/google/genai/__init__.py)
# Le Kernel s’est bloqué lors de l’exécution du code dans la cellule active ou une cellule précédente. Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec. Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations. Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
#RAG you need a llm, a knowledge base to retrieve from

class RAG:
    def __init__(self):

        self.llm = 'get_local_model'

        self.db = 'get_DataBase'

        self.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_ollama import ChatOllama

LOCAL_MODEL_NAME = 'mistral'
class LLM:
    def __init__(self, temperature: float = 0.0, format = str):

        self.temperature = temperature
        self.format = format
    
    def get_local_model(self):
        return ChatOllama(model=LOCAL_MODEL_NAME,
        temperature=self.temperature, format=self.format)
    
    # def get_cloud_model(self):

    #     return ChatGoogleGenerativeAI(model=settings.CLOUD_MODEL_NAME,
    #     api_key=settings.GEMINI_API_KEY)

# %%
llm = LLM(temperature=0.0, format=str)

# %%
model = llm.get_local_model()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = llm.get_local_model()
#
# Cell In[2], line 12, in LLM.get_local_model(self)
#      11 def get_local_model(self):
# ---> 12     return ChatOllama(model=LOCAL_MODEL_NAME,
#      13     temperature=self.temperature, format=self.format)
#
# File ~/private_cfo_project/.venv/lib/python3.11/site-packages/langchain_core/load/serializable.py:117, in Serializable.__init__(self, *args, **kwargs)
#     115 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     116     """"""  # noqa: D419  # Intentional blank docstring
# --> 117     super().__init__(*args, **kwargs)
#
# File ~/private_cfo_project/.venv/lib/python3.11/site-packages/pydantic/main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
# ...
